# %% [markdown]
# # working with 3d arrays

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
img = plt.imread('two.jpg') #saving the image in img

# %%
img
# Out:
# array([[[72, 54,  6],
#         [72, 55,  3],
#         [74, 57,  1],
#         ...,
#         [56, 84, 85],
#         [57, 85, 86],
#         [58, 86, 87]],
#
#        [[76, 56,  6],
#         [76, 56,  5],
#         [78, 59,  1],
#         ...,
#         [52, 80, 81],
#         [53, 81, 82],
#         [53, 81, 82]],
#
#        [[76, 55,  2],
#         [77, 56,  1],
#         [81, 61,  0],
#         ...,
#         [44, 72, 73],
#         [45, 73, 74],
#         [45, 73, 74]],
#
#        ...,
#
#        [[70, 59,  5],
#         [72, 61,  7],
#         [70, 58,  6],
#         ...,
#         [30, 65, 85],
#         [30, 65, 85],
#         [30, 65, 85]],
#
#        [[48, 40,  0],
#         [50, 42,  0],
#         [50, 42,  0],
#         ...,
#         [26, 61, 81],
#         [25, 60, 80],
#         [25, 60, 80]],
#
#        [[34, 30,  0],
#         [36, 32,  0],
#         [36, 31,  0],
#         ...,
#         [21, 56, 78],
#         [20, 55, 77],
#         [20, 55, 77]]], dtype=uint8)

# %%
# checking the various parameter

# %%
img.ndim
# Out:
# 3

# %%
img.shape
# Out:
# (411, 871, 3)

# %%
img.size
# Out:
# 1073943

# %%
img.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# # to view the saved image

# %%
plt.imshow(img)

# %%
type(img) #the imge is an ndarrya , so we have all the properties of ndarray applied on the saved image
# Out:
# numpy.ndarray

# %%
arr1 = np.array([1,2,3,4,5])

# %%
arr1[0]
# Out:
# 1

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
plt.imshow(img[0]) #rading the row zero

# %%
plt.imshow(img[:,:,:])

# %%
plt.imshow(img[0:200,:,:]) #image cropping

# %%
plt.imshow(img[0:100,:,:])

# %%
plt.imshow(img[:,:350,:])

# %%
plt.imshow(img[150:330,100:330,:])

# %%
plt.imshow(np.transpose(img,(0,1,2)))

# %%
plt.imshow(np.transpose(img,(1,0,2))) #image transpose by swapping the 0th and 1st dimension
