# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('gapminder_full.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# reading the 1st row data
# using loc
# usingng iloc

# %%
df.loc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
# reading a range of rows using iloc

# %%
df.iloc[0:10]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.iloc[1500:1505]
# Out:
#      country  year  population continent  life_exp      gdp_cap
# 1500  Taiwan  1952     8550362      Asia     58.50  1206.947913
# 1501  Taiwan  1957    10164215      Asia     62.40  1507.861290
# 1502  Taiwan  1962    11918938      Asia     65.20  1822.879028
# 1503  Taiwan  1967    13648692      Asia     67.50  2643.858681
# 1504  Taiwan  1972    15226039      Asia     69.39  4062.523897

# %%
df.iloc[1700:]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.iloc[0:1705:100]
# Out:
#                     country  year  population continent  life_exp  \
# 0               Afghanistan  1952     8425333      Asia    28.801
# 100              Bangladesh  1972    70759295      Asia    45.252
# 200            Burkina Faso  1992     8878303    Africa    50.260
# 300                Colombia  1952    12350771  Americas    50.643
# 400          Czech Republic  1972     9862158    Europe    70.290
# 500                 Eritrea  1992     3668440    Africa    49.991
# 600               Guatemala  1952     3146381  Americas    42.023
# 700                   India  1972   567000000      Asia    50.651
# 800                   Japan  1992   124329269      Asia    79.360
# 900                   Libya  1952     1019729    Africa    42.723
# 1000               Mongolia  1972     1320500      Asia    53.754
# 1100            New Zealand  1992     3437674   Oceania    76.330
# 1200                   Peru  1952     8025700  Americas    43.902
# ...

# %%
# adding one row using append
# in the form of a dictionary

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
d = {'country':'India', 'year':2020, 'population':1400000, 'continent':'Asia', 'life_exp':44.11, 'gdp_cap':101.1}

# %%
df.append(d,ignore_index=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_27668\1429863610.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(d,ignore_index=True)
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# ...

# %%
# adding a row using iloc is not possible
# can be added using loc only 
# why

# %%
df.iloc[1703]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1703, dtype: object

# %%
df.iloc[1704] = pd.Series(d)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 df.iloc[1704] = pd.Series(d)
#
# File C:\Python\Python310\lib\site-packages\pandas\core\indexing.py:816, in _LocationIndexer.__setitem__(self, key, value)
#     814     key = com.apply_if_callable(key, self.obj)
#     815 indexer = self._get_setitem_indexer(key)
# --> 816 self._has_valid_setitem_indexer(key)
#     818 iloc = self if self.name == "iloc" else self.obj.iloc
#     819 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\Python\Python310\lib\site-packages\pandas\core\indexing.py:1519, in _iLocIndexer._has_valid_setitem_indexer(self, indexer)
#    1517 elif is_integer(i):
#    1518     if i >= len(ax):
# -> 1519         raise IndexError("iloc cannot enlarge its target object")
#    1520 elif isinstance(i, dict):
# ...

# %%
df.loc[1704] = pd.Series(d)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1400000      Asia    44.110  101.100000
#
# [1705 rows x 6 columns]

# %%
df.loc[1705] = pd.Series(d)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1400000      Asia    44.110  101.100000
# 1705        India  2020     1400000      Asia    44.110  101.100000
#
# [1706 rows x 6 columns]

# %%
df.loc[1706] = pd.Series(d)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1400000      Asia    44.110  101.100000
# 1705        India  2020     1400000      Asia    44.110  101.100000
# 1706        India  2020     1400000      Asia    44.110  101.100000
#
# [1707 rows x 6 columns]

# %%
# removing the duplicate row

# %%
df.duplicated() #boolean Mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1702    False
# 1703    False
# 1704    False
# 1705     True
# 1706     True
# Length: 1707, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      country  year  population continent  life_exp  gdp_cap
# 1705   India  2020     1400000      Asia     44.11    101.1
# 1706   India  2020     1400000      Asia     44.11    101.1

# %%
df.drop_duplicates(keep='last')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1706        India  2020     1400000      Asia    44.110  101.100000
#
# [1705 rows x 6 columns]

# %%
# removing any row as per our need

# %%
df.drop(0,axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1400000      Asia    44.110  101.100000
# 1705        India  2020     1400000      Asia    44.110  101.100000
# 1706        India  2020     1400000      Asia    44.110  101.100000
#
# [1706 rows x 6 columns]

# %%
# removing any row as per our need

# %%
df.drop(1706,axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1400000      Asia    44.110  101.100000
# 1705        India  2020     1400000      Asia    44.110  101.100000
#
# [1706 rows x 6 columns]

# %%
df.drop('country',axis=1) #removing any column
# Out:
#       year  population continent  life_exp     gdp_cap
# 0     1952     8425333      Asia    28.801  779.445314
# 1     1957     9240934      Asia    30.332  820.853030
# 2     1962    10267083      Asia    31.997  853.100710
# 3     1967    11537966      Asia    34.020  836.197138
# 4     1972    13079460      Asia    36.088  739.981106
# ...    ...         ...       ...       ...         ...
# 1702  2002    11926563    Africa    39.989  672.038623
# 1703  2007    12311143    Africa    43.487  469.709298
# 1704  2020     1400000      Asia    44.110  101.100000
# 1705  2020     1400000      Asia    44.110  101.100000
# 1706  2020     1400000      Asia    44.110  101.100000
#
# [1707 rows x 5 columns]

# %% [markdown]
# # working with rows and columns

# %%
# using loc and iloc

# %%
df.iloc[0:5]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.loc[0:5]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360

# %%
df.iloc[0:5,0:3]
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460

# %%
df.loc[0:5,'country':'population'] #using the actual column namnes in loc , last value is also included
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460
# 5  Afghanistan  1977    14880372

# %% [markdown]
# # Operations in Pandas

# %%
df.describe()
# Out:
#               year    population     life_exp        gdp_cap
# count  1707.000000  1.707000e+03  1707.000000    1707.000000
# mean   1979.571178  2.955165e+07    59.447437    7202.824046
# std      17.333399  1.060711e+08    12.921790    9853.292996
# min    1952.000000  6.001100e+04    23.599000     101.100000
# 25%    1967.000000  2.780274e+06    48.126500    1194.939659
# 50%    1982.000000  7.021028e+06    60.542000    3528.481305
# 75%    1997.000000  1.956179e+07    70.840500    9319.503534
# max    2020.000000  1.318683e+09    82.603000  113523.132900

# %%
df['life_exp'].mean()
# Out:
# 59.44743683655536

# %%
df['life_exp'].max()
# Out:
# 82.603

# %%
df['life_exp'].min()
# Out:
# 23.599

# %%
df['life_exp'].sum()
# Out:
# 101476.77468

# %%
# to limit the accuracy in decimal
